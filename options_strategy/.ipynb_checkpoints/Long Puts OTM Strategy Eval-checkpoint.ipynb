# %% [markdown]
# # Long Puts OTM Strategy Eval
#
# What if I continually buy puts that are way out of the money? Do you win big enough to outweigh the small losses?
#
# Evaluation steps:
#
# 1. With a single stock:
#     1. Pull stocks from Xano
#     2. Get historical prices on each stock
#     3. Get option chains on each stock (is it possible to get historical chains?)
#     4. Simulate the stock prices
# 2. With all the stocks:
#     1. Pull stocks from Xano
#     2. Get historical prices on each stock
#     3. Get option chains on each stock (is it possible to get historical chains?)
#     4. Simulate the stock prices
# 3. Choose the stocks most likely to go down by expiration date
# 4. "Buy" puts and see

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
import numpy as np
from scipy.stats import genextreme
from random import choices

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Single Stock

# %% [markdown]
# ### Pick a single stock from Xano

# %%
url = 'https://iocalc.com/api:gPr_YnZX/getstocks'

response = requests.get(url)

stock_table = pd.json_normalize(response.json()['stocks'])
this_stock = stock_table.sample()
this_stock
# Out:
#     id     created_at                                          name symbol  \
# 47  52  1643133310760  Fidelity National Information Services, Inc.    FIS
#
#      price  target    marketcap week52high week52low  dividendyield  \
# 47  109.81  147.53  68073085228      154.5    101.41       0.013886
#
#     day200movingavg  day50movingavg  exdividend nextearnings     eps  \
# 47           121.25          111.18  2021-12-10   2022-02-15  0.3687
#
#                  pe              beta         change_1yr        change_ytd  \
# 47  295.96993577474  0.83908564273413  -0.12340475583698  0.02418689876317
#
#     pricetargethigh  pricetargetlow symboltype  analysts currency  \
# 47            183.0           115.0      stock        30      USD
#
#     totaltracking
# 47              0

# %% [markdown]
# ### Get historical data for stock

# %%
config = pd.read_csv('../tradier_exploration/sandbox.config')
token = config.prod_token[0]
symbol = this_stock['symbol'].item()

# %%
endpoint = 'https://api.tradier.com'
path = '/v1/markets/history'

response = requests.get(f'{endpoint}{path}',
    params = {'symbol':f'{symbol}', 
              'interval': 'daily', 
              'start': '2000-01-01', 
              'end': f'{datetime.today().date().isoformat()}'},
    headers = {'Authorization': f'Bearer {token}', 
               'Accept': 'application/json'}
)
json_response = response.json()
this_stock_history = pd.json_normalize(json_response['history']['day'])
this_stock_history['symbol'] = symbol
this_stock_history['perc_change'] = (this_stock_history['close'] - this_stock_history['open']) / this_stock_history['open']
this_stock_history
# Out:
#             date   open    high    low  close   volume symbol  perc_change
# 0     2005-03-14  36.25  36.700  36.23  36.40   187400    FIS     0.004138
# 1     2005-05-31  37.48  37.850  37.32  37.55   117800    FIS     0.001868
# 2     2005-10-31  36.99  38.150  36.97  37.46  1705200    FIS     0.012706
# 3     2005-11-04  38.35  38.780  37.88  38.37   628900    FIS     0.000522
# 4     2006-02-01  41.50  41.500  39.26  39.48  1376800    FIS    -0.048675
# ...          ...    ...     ...    ...    ...      ...    ...          ...
# 4235  2022-11-21  61.23  61.805  60.34  61.56  7537391    FIS     0.005390
# 4236  2022-11-22  61.87  65.360  61.78  65.19  8847230    FIS     0.053661
# 4237  2022-11-23  64.66  66.600  64.62  65.93  6970946    FIS     0.019641
# 4238  2022-11-25  65.99  66.180  65.29  65.98  2400022    FIS    -0.000152
# 4239  2022-11-28  65.33  67.170  65.32  65.60  4717981    FIS     0.004133
#
# [4240 rows x 8 columns]

# %% [markdown]
# ### Get option chains for stock

# %% [markdown]
# #### Get option expirations for stock

# %%
path = '/v1/markets/options/expirations'

response = requests.get(f'{endpoint}{path}',
    params = {'symbol': f'{symbol}', 
              'includeAllRoots': 'true'},
    headers = {'Authorization': f'Bearer {token}', 
               'Accept': 'application/json'}
)

option_dates = pd.DataFrame({'exp_dates': response.json()['expirations']['date'],
                             'symbol': symbol})
option_dates
# Out:
#     exp_dates symbol
# 0  2022-12-16    FIS
# 1  2023-01-20    FIS
# 2  2023-04-21    FIS
# 3  2023-07-21    FIS
# 4  2024-01-19    FIS
# 5  2025-01-17    FIS

# %% [markdown]
# #### Get put chains for stock

# %%
path = '/v1/markets/options/chains'

all_puts = pd.DataFrame()

for date in option_dates['exp_dates']:
    response = requests.get(f'{endpoint}{path}',
        params = {'symbol': f'{symbol}', 
                  'expiration': f'{date}', 
                  'greeks': 'true'},
        headers = {'Authorization': f'Bearer {token}', 
                   'Accept': 'application/json'}
    )

    json_response = response.json()

    tmp = pd.json_normalize(json_response['options']['option'])
    tmp = tmp.loc[tmp['option_type'] == 'put']

    all_puts = pd.concat([all_puts, tmp], axis = 0, ignore_index = True)

all_puts['strike_minus_last'] = all_puts['strike'] - all_puts['ask']
all_puts
# Out:
#                  symbol                  description exch    type  last  \
# 0    FIS221216P00040000   FIS Dec 16 2022 $40.00 Put    Z  option  0.04
# 1    FIS221216P00045000   FIS Dec 16 2022 $45.00 Put    Z  option  0.09
# 2    FIS221216P00050000   FIS Dec 16 2022 $50.00 Put    Z  option  0.05
# 3    FIS221216P00055000   FIS Dec 16 2022 $55.00 Put    Z  option  0.19
# 4    FIS221216P00060000   FIS Dec 16 2022 $60.00 Put    Z  option  0.50
# ..                  ...                          ...  ...     ...   ...
# 139  FIS250117P00120000  FIS Jan 17 2025 $120.00 Put    Z  option   NaN
# 140  FIS250117P00125000  FIS Jan 17 2025 $125.00 Put    Z  option   NaN
# 141  FIS250117P00130000  FIS Jan 17 2025 $130.00 Put    Z  option   NaN
# 142  FIS250117P00135000  FIS Jan 17 2025 $135.00 Put    Z  option   NaN
# 143  FIS250117P00140000  FIS Jan 17 2025 $140.00 Put    Z  option   NaN
#
#      change  volume  open  high   low close    bid    ask underlying  strike  \
# 0      0.00       0   NaN   NaN   NaN  None   0.00   0.15        FIS    40.0
# 1      0.00       0   NaN   NaN   NaN  None   0.00   0.05        FIS    45.0
# 2     -0.03       2  0.05  0.05  0.05  None   0.05   0.10        FIS    50.0
# 3      0.04       2  0.16  0.19  0.16  None   0.15   0.20        FIS    55.0
# 4      0.02     222  0.65  0.65  0.35  None   0.50   0.60        FIS    60.0
# ..      ...     ...   ...   ...   ...   ...    ...    ...        ...     ...
# 139     NaN       0   NaN   NaN   NaN  None  52.70  57.00        FIS   120.0
# 140     NaN       0   NaN   NaN   NaN  None  57.00  62.00        FIS   125.0
# 141     NaN       0   NaN   NaN   NaN  None  62.10  67.00        FIS   130.0
# 142     NaN       0   NaN   NaN   NaN  None  67.40  72.00        FIS   135.0
# 143     NaN       0   NaN   NaN   NaN  None  72.00  77.00        FIS   140.0
#
#      change_percentage  average_volume  last_volume     trade_date  prevclose  \
# 0                 0.00               0            1  1669391846049       0.04
# 1                 0.00               0            7  1669223053538       0.09
# 2               -37.50               0            2  1669650914204       0.08
# 3                26.67               0            1  1669657650564       0.15
# 4                 4.17               0            3  1669650316871       0.48
# ..                 ...             ...          ...            ...        ...
# 139                NaN               0            0              0        NaN
# 140                NaN               0            0              0        NaN
# 141                NaN               0            0              0        NaN
# 142                NaN               0            0              0        NaN
# 143                NaN               0            0              0        NaN
#
#      week_52_high  week_52_low  bidsize bidexch       bid_date  asksize  \
# 0             0.0          0.0        0       P  1669652084000        1
# 1             0.0          0.0        0       P  1669652084000        1
# 2             0.0          0.0        1       N  1669650914000        1
# 3             0.0          0.0        1       C  1669654958000       52
# 4             0.0          0.0      102       X  1669663151000       38
# ..            ...          ...      ...     ...            ...      ...
# 139           0.0          0.0       15       B  1669662866000        1
# 140           0.0          0.0       10       X  1669663069000       10
# 141           0.0          0.0       16       B  1669663149000       10
# 142           0.0          0.0       15       B  1669662891000       10
# 143           0.0          0.0       10       X  1669663010000       10
#
#     askexch       ask_date  open_interest  contract_size expiration_date  \
# 0         X  1669655511000            243            100      2022-12-16
# 1         N  1669654733000             78            100      2022-12-16
# 2         N  1669651499000             29            100      2022-12-16
# 3         Z  1669662847000            300            100      2022-12-16
# 4         X  1669663150000            985            100      2022-12-16
# ..      ...            ...            ...            ...             ...
# 139       N  1669663145000              0            100      2025-01-17
# 140       X  1669663040000              0            100      2025-01-17
# 141       X  1669663149000              0            100      2025-01-17
# 142       X  1669662892000              0            100      2025-01-17
# 143       X  1669662983000              0            100      2025-01-17
#
#     expiration_type option_type root_symbol  greeks.delta  greeks.gamma  \
# 0          standard         put         FIS      0.000000 -1.142407e-15
# 1          standard         put         FIS      0.000000 -1.142407e-15
# 2          standard         put         FIS      0.000000 -1.142407e-15
# 3          standard         put         FIS      0.000102  2.549500e-03
# 4          standard         put         FIS     -0.132035  4.488393e-02
# ..              ...         ...         ...           ...           ...
# 139        standard         put         FIS     -0.832862  7.782990e-03
# 140        standard         put         FIS     -0.862859  7.066368e-03
# 141        standard         put         FIS     -0.883052  6.390810e-03
# 142        standard         put         FIS     -0.900773  5.734706e-03
# 143        standard         put         FIS     -0.914159  5.160150e-03
#
#      greeks.theta  greeks.vega  greeks.rho  greeks.phi  greeks.bid_iv  \
# 0    0.000000e+00     0.000020    0.000000    0.000000       0.000000
# 1    0.000000e+00     0.000020    0.000000    0.000000       0.000000
# 2    0.000000e+00     0.000020    0.000000    0.000000       0.580758
# 3   -1.954353e-14     0.000020    0.000000    0.000000       0.486176
# 4   -2.517178e-02     0.030146    0.012735   -0.013934       0.388698
# ..            ...          ...         ...         ...            ...
# 139 -5.264311e-03     0.238824    0.182697   -0.230409       0.000000
# 140 -4.507775e-03     0.219186    0.153216   -0.190246       0.000000
# 141 -4.006106e-03     0.197080    0.132045   -0.162557       0.000000
# 142 -3.527623e-03     0.175127    0.113128   -0.138165       0.000000
# 143 -3.163982e-03     0.153510    0.098483   -0.119640       0.000000
#
#      greeks.mid_iv  greeks.ask_iv  greeks.smv_vol    greeks.updated_at  \
# 0         1.171645       1.171645           0.479  2022-11-28 18:58:56
# 1         0.777427       0.777427           0.479  2022-11-28 18:58:56
# 2         0.615006       0.649254           0.479  2022-11-28 18:58:56
# 3         0.501697       0.517219           0.443  2022-11-28 18:58:56
# 4         0.403065       0.417432           0.400  2022-11-28 18:58:56
# ..             ...            ...             ...                  ...
# 139       0.487368       0.487368           0.319  2022-11-28 18:58:56
# 140       0.513280       0.513280           0.302  2022-11-28 18:58:56
# 141       0.535349       0.535349           0.290  2022-11-28 18:58:56
# 142       0.556659       0.556659           0.288  2022-11-28 18:58:56
# 143       0.576394       0.576394           0.288  2022-11-28 18:58:56
#
#      strike_minus_last
# 0                39.85
# 1                44.95
# 2                49.90
# 3                54.80
# 4                59.40
# ..                 ...
# 139              63.00
# 140              63.00
# 141              63.00
# 142              63.00
# 143              63.00
#
# [144 rows x 46 columns]

# %% [markdown]
# ### Simulate Stock Prices

# %%
num_samples = 10000
sample_size = 20000
upper_scale = 0.60
upper_shape = -0.09
lower_scale = 0.65
lower_shape = -0.1
today = datetime.today().date()
start_price = this_stock_history['close'].iloc[-1]

final_put_chain = pd.DataFrame()

for option_date in option_dates['exp_dates']:
    
    opt_chain = all_puts.loc[all_puts['expiration_date'] == option_date]

    date = {"Date": pd.date_range(today, option_date)}

    dates = pd.DataFrame(data = date)
    dates['wday'] = dates['Date'].dt.dayofweek
    dates = dates.loc[dates['wday'] != 5]
    dates = dates.loc[dates['wday'] != 6]

    num_trading_days = dates.shape[0]

    start = today - timedelta(days = num_trading_days)

    start = start.isoformat()
    
    perc_pos = (
        sum(this_stock_history.loc[this_stock_history['date'] > start, 'perc_change'] > 0) / 
        len(this_stock_history.loc[this_stock_history['date'] > start, 'perc_change'])
    )

    perc_neg = 1 - perc_pos

    avg = np.mean(this_stock_history['perc_change'])
    std = np.std(this_stock_history['perc_change'])

    samp_upper = genextreme.rvs(upper_shape, 
                                loc = avg, 
                                scale = upper_scale * std,
                                size = round(sample_size * perc_pos))

    samp_lower = -1 * genextreme.rvs(lower_shape, 
                                     loc = avg, 
                                     scale = lower_scale * std,
                                     size = round(sample_size * perc_neg))

    samp = np.append(samp_upper, samp_lower)
    del samp_upper
    del samp_lower

    sample_col = pd.Series(range(1, num_trading_days + 1)).repeat(num_samples)
    dates_col = dates['Date'].repeat(num_samples)
    sample_values = np.array(choices(samp + 1, 
                                     k = num_samples * num_trading_days
                                     )).reshape(num_trading_days, 
                                                num_samples)
    sample_values[0] = start_price

    price_paths = sample_values.cumprod(axis = 0)

    final_prices = price_paths[num_trading_days - 1]
    del price_paths

    for strp in opt_chain.strike:
        opt_chain.loc[opt_chain['strike'] == strp, 'likelihood_below'] = (
            sum(final_prices < opt_chain.loc[opt_chain['strike'] == strp, 'strike_minus_last'].item()) / num_samples)
        
        opt_chain.loc[opt_chain['strike'] == strp, 'likelihood_strike'] = (
            sum(final_prices < strp) / num_samples)
    
    final_put_chain = pd.concat([final_put_chain, opt_chain], axis = 0, ignore_index = True)

final_put_chain
# Out:
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_86229/2664646877.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   opt_chain.loc[opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_86229/2664646877.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   opt_chain.loc[opt_chain['strike'] == strp, 'likelihood_strike'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_86229/2664646877.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   opt_chain.loc[opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_86229/2664646877.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   opt_chain.loc[opt_chain['strike'] == strp, 'likelihood_strike'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_86229/2664646877.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   opt_chain.loc[opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_86229/2664646877.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   opt_chain.loc[opt_chain['strike'] == strp, 'likelihood_strike'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_86229/2664646877.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   opt_chain.loc[opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_86229/2664646877.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   opt_chain.loc[opt_chain['strike'] == strp, 'likelihood_strike'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_86229/2664646877.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   opt_chain.loc[opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_86229/2664646877.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   opt_chain.loc[opt_chain['strike'] == strp, 'likelihood_strike'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_86229/2664646877.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   opt_chain.loc[opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_86229/2664646877.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   opt_chain.loc[opt_chain['strike'] == strp, 'likelihood_strike'] = (
#                  symbol                  description exch    type  last  \
# 0    FIS221216P00040000   FIS Dec 16 2022 $40.00 Put    Z  option  0.04
# 1    FIS221216P00045000   FIS Dec 16 2022 $45.00 Put    Z  option  0.09
# 2    FIS221216P00050000   FIS Dec 16 2022 $50.00 Put    Z  option  0.05
# 3    FIS221216P00055000   FIS Dec 16 2022 $55.00 Put    Z  option  0.19
# 4    FIS221216P00060000   FIS Dec 16 2022 $60.00 Put    Z  option  0.50
# ..                  ...                          ...  ...     ...   ...
# 139  FIS250117P00120000  FIS Jan 17 2025 $120.00 Put    Z  option   NaN
# 140  FIS250117P00125000  FIS Jan 17 2025 $125.00 Put    Z  option   NaN
# 141  FIS250117P00130000  FIS Jan 17 2025 $130.00 Put    Z  option   NaN
# 142  FIS250117P00135000  FIS Jan 17 2025 $135.00 Put    Z  option   NaN
# 143  FIS250117P00140000  FIS Jan 17 2025 $140.00 Put    Z  option   NaN
#
#      change  volume  open  high   low close    bid    ask underlying  strike  \
# 0      0.00       0   NaN   NaN   NaN  None   0.00   0.15        FIS    40.0
# 1      0.00       0   NaN   NaN   NaN  None   0.00   0.05        FIS    45.0
# 2     -0.03       2  0.05  0.05  0.05  None   0.05   0.10        FIS    50.0
# 3      0.04       2  0.16  0.19  0.16  None   0.15   0.20        FIS    55.0
# 4      0.02     222  0.65  0.65  0.35  None   0.50   0.60        FIS    60.0
# ..      ...     ...   ...   ...   ...   ...    ...    ...        ...     ...
# 139     NaN       0   NaN   NaN   NaN   NaN  52.70  57.00        FIS   120.0
# 140     NaN       0   NaN   NaN   NaN   NaN  57.00  62.00        FIS   125.0
# 141     NaN       0   NaN   NaN   NaN   NaN  62.10  67.00        FIS   130.0
# 142     NaN       0   NaN   NaN   NaN   NaN  67.40  72.00        FIS   135.0
# 143     NaN       0   NaN   NaN   NaN   NaN  72.00  77.00        FIS   140.0
#
#      change_percentage  average_volume  last_volume     trade_date  prevclose  \
# 0                 0.00               0            1  1669391846049       0.04
# 1                 0.00               0            7  1669223053538       0.09
# 2               -37.50               0            2  1669650914204       0.08
# 3                26.67               0            1  1669657650564       0.15
# 4                 4.17               0            3  1669650316871       0.48
# ..                 ...             ...          ...            ...        ...
# 139                NaN               0            0              0        NaN
# 140                NaN               0            0              0        NaN
# 141                NaN               0            0              0        NaN
# 142                NaN               0            0              0        NaN
# 143                NaN               0            0              0        NaN
#
#      week_52_high  week_52_low  bidsize bidexch       bid_date  asksize  \
# 0             0.0          0.0        0       P  1669652084000        1
# 1             0.0          0.0        0       P  1669652084000        1
# 2             0.0          0.0        1       N  1669650914000        1
# 3             0.0          0.0        1       C  1669654958000       52
# 4             0.0          0.0      102       X  1669663151000       38
# ..            ...          ...      ...     ...            ...      ...
# 139           0.0          0.0       15       B  1669662866000        1
# 140           0.0          0.0       10       X  1669663069000       10
# 141           0.0          0.0       16       B  1669663149000       10
# 142           0.0          0.0       15       B  1669662891000       10
# 143           0.0          0.0       10       X  1669663010000       10
#
#     askexch       ask_date  open_interest  contract_size expiration_date  \
# 0         X  1669655511000            243            100      2022-12-16
# 1         N  1669654733000             78            100      2022-12-16
# 2         N  1669651499000             29            100      2022-12-16
# 3         Z  1669662847000            300            100      2022-12-16
# 4         X  1669663150000            985            100      2022-12-16
# ..      ...            ...            ...            ...             ...
# 139       N  1669663145000              0            100      2025-01-17
# 140       X  1669663040000              0            100      2025-01-17
# 141       X  1669663149000              0            100      2025-01-17
# 142       X  1669662892000              0            100      2025-01-17
# 143       X  1669662983000              0            100      2025-01-17
#
#     expiration_type option_type root_symbol  greeks.delta  greeks.gamma  \
# 0          standard         put         FIS      0.000000 -1.142407e-15
# 1          standard         put         FIS      0.000000 -1.142407e-15
# 2          standard         put         FIS      0.000000 -1.142407e-15
# 3          standard         put         FIS      0.000102  2.549500e-03
# 4          standard         put         FIS     -0.132035  4.488393e-02
# ..              ...         ...         ...           ...           ...
# 139        standard         put         FIS     -0.832862  7.782990e-03
# 140        standard         put         FIS     -0.862859  7.066368e-03
# 141        standard         put         FIS     -0.883052  6.390810e-03
# 142        standard         put         FIS     -0.900773  5.734706e-03
# 143        standard         put         FIS     -0.914159  5.160150e-03
#
#      greeks.theta  greeks.vega  greeks.rho  greeks.phi  greeks.bid_iv  \
# 0    0.000000e+00     0.000020    0.000000    0.000000       0.000000
# 1    0.000000e+00     0.000020    0.000000    0.000000       0.000000
# 2    0.000000e+00     0.000020    0.000000    0.000000       0.580758
# 3   -1.954353e-14     0.000020    0.000000    0.000000       0.486176
# 4   -2.517178e-02     0.030146    0.012735   -0.013934       0.388698
# ..            ...          ...         ...         ...            ...
# 139 -5.264311e-03     0.238824    0.182697   -0.230409       0.000000
# 140 -4.507775e-03     0.219186    0.153216   -0.190246       0.000000
# 141 -4.006106e-03     0.197080    0.132045   -0.162557       0.000000
# 142 -3.527623e-03     0.175127    0.113128   -0.138165       0.000000
# 143 -3.163982e-03     0.153510    0.098483   -0.119640       0.000000
#
#      greeks.mid_iv  greeks.ask_iv  greeks.smv_vol    greeks.updated_at  \
# 0         1.171645       1.171645           0.479  2022-11-28 18:58:56
# 1         0.777427       0.777427           0.479  2022-11-28 18:58:56
# 2         0.615006       0.649254           0.479  2022-11-28 18:58:56
# 3         0.501697       0.517219           0.443  2022-11-28 18:58:56
# 4         0.403065       0.417432           0.400  2022-11-28 18:58:56
# ..             ...            ...             ...                  ...
# 139       0.487368       0.487368           0.319  2022-11-28 18:58:56
# 140       0.513280       0.513280           0.302  2022-11-28 18:58:56
# 141       0.535349       0.535349           0.290  2022-11-28 18:58:56
# 142       0.556659       0.556659           0.288  2022-11-28 18:58:56
# 143       0.576394       0.576394           0.288  2022-11-28 18:58:56
#
#      strike_minus_last  likelihood_below  likelihood_strike
# 0                39.85            0.0000             0.0000
# 1                44.95            0.0000             0.0000
# 2                49.90            0.0001             0.0001
# 3                54.80            0.0014             0.0016
# 4                59.40            0.0289             0.0405
# ..                 ...               ...                ...
# 139              63.00            0.6552             0.9865
# 140              63.00            0.6552             0.9895
# 141              63.00            0.6552             0.9923
# 142              63.00            0.6552             0.9941
# 143              63.00            0.6552             0.9952
#
# [144 rows x 48 columns]

# %% [markdown]
# ## Pull stocks from Xano

# %%
url = 'https://iocalc.com/api:gPr_YnZX/getstocks'

response = requests.get(url)

stock_table = pd.json_normalize(response.json()['stocks'])

# %%
stock_table
# Out:
#     id     created_at                             name symbol   price  target  \
# 0   20  1669528036105        Meta Financial Group Inc.   CASH   44.66   72.50
# 1   19  1669528050982                   Global X Funds   QYLD   16.45    0.00
# 2   11  1669528132313       Verizon Communications Inc     VZ   39.02   60.00
# 3   49  1669528349343            Delta Air Lines, Inc.    DAL   35.10   51.56
# 4   54  1669529418716                      Humana Inc.    HUM  540.95  485.87
# ..  ..            ...                              ...    ...     ...     ...
# 65  74  1643141926509  Oceaneering International, Inc.    OII   13.88   17.72
# 66  70  1669528047177                Kosmos Energy Ltd    KOS    6.41    5.96
# 67  76  1669528829688              GlobalFoundries Inc    GFS   67.61   79.10
# 68  65  1643141629684               ALPS Fund Services   SBIO   33.95    0.00
# 69  68  1656705855826               Rocket Lab USA Inc   RKLB    3.81   21.20
#
#        marketcap week52high week52low  dividendyield  ...                pe  \
# 0     1741265522       65.9     36.02       0.003454  ...   6.2630944593554
# 1     5871377700      22.43     19.11       0.121877  ...
# 2   223153658344      58.44     49.09       0.058884  ...   10.124939126336
# 3    24262923840      52.28      33.4       0.000000  ...    -356.807703535
# 4    48727349718     473.14     351.2       0.007368  ...   18.229461173999
# ..           ...        ...       ...            ...  ...               ...
# 65    1282413359       18.2      8.27       0.000000  ...  -36.130426529836
# 66    1916009623       4.89       1.8       0.000000  ...  -11.364502259128
# 67   33128671394      79.49     43.59       0.000000  ...  -132.34898464626
# 68     146072500      64.04     31.96       0.000000  ...
# 69    3917063728      21.34         8       0.000000  ...                 0
#
#                 beta           change_1yr          change_ytd pricetargethigh  \
# 0    1.1439973981583     0.48746215755319  -0.030673818303721            79.0
# 1                     -0.0083631439208244  -0.079315006759802             0.0
# 2                  0   -0.032254541085492   0.035421706459115            71.0
# 3    1.1989249496749             -0.05225  -0.029938587512794            67.0
# 4   0.54182997393569   -0.058274921620204   -0.18272754710473           581.0
# ..               ...                  ...                 ...             ...
# 65   1.8863947677163     0.21916508538899    0.13616268788683            20.0
# 66   2.3177199524754     0.58208955223881    0.22543352601156             8.0
# 67                 0     0.34245689655172  -0.041249807603509           100.0
# 68                      -0.38581129378127   -0.18631628787879             0.0
# 69                 0    -0.16395014381592   -0.28990228013029            28.0
#
#    pricetargetlow symboltype analysts currency  totaltracking
# 0            70.0      stock        4      USD              0
# 1             0.0                   0                       0
# 2            52.0      stock       26      USD              0
# 3            40.0      stock       18      USD              0
# 4           410.0      stock       23      USD              0
# ..            ...        ...      ...      ...            ...
# 65           16.0      stock        9      USD              0
# 66            4.1      stock        7      USD              0
# 67           46.0      stock       15      USD              0
# 68            0.0                   0                       0
# 69           18.0      stock        5      USD              0
#
# [70 rows x 25 columns]

# %% [markdown]
# ## Get Historical Prices for Each Stock

# %%
endpoint = 'https://api.tradier.com'
path = '/v1/markets/history'

all_stock_history = pd.DataFrame()

for symbol in stock_table['symbol']:
    response = requests.get(f'{endpoint}{path}',
        params={'symbol':f'{symbol}', 
                'interval': 'daily', 
                'start': '2000-01-01', 
                'end': f'{datetime.today().date().isoformat()}'},
        headers={'Authorization': f'Bearer {token}', 
                 'Accept': 'application/json'}
    )
    json_response = response.json()
    this_stock = pd.json_normalize(json_response['history']['day'])
    this_stock['symbol'] = symbol
    
    all_stock_history = pd.concat([all_stock_history, this_stock], axis = 0, ignore_index = True)

# %%
all_stock_history
# Out:
#               date      open      high       low     close   volume symbol
# 0       2000-01-03  4.166667  4.166667       4.0  4.000000     5700   CASH
# 1       2000-01-04  3.958333  3.958333  3.833333  3.833333    21900   CASH
# 2       2000-01-05  3.770833  3.770833  3.770833  3.770833     2700   CASH
# 3       2000-01-06  3.916667       4.0  3.833333  3.916667     3300   CASH
# 4       2000-01-07  3.833333  3.833333      3.75  3.750000    27300   CASH
# ...            ...       ...       ...       ...       ...      ...    ...
# 256723  2022-11-18       4.7      4.71     4.425  4.600000  2205709   RKLB
# 256724  2022-11-21      4.61      4.65      4.29  4.320000  3719993   RKLB
# 256725  2022-11-22      4.32      4.41       4.2  4.360000  2867496   RKLB
# 256726  2022-11-23      4.36     4.445      4.32  4.400000  3245839   RKLB
# 256727  2022-11-25       4.5    4.5525      4.14  4.180000  3209948   RKLB
#
# [256728 rows x 7 columns]

# %% [markdown]
# ## Get Option Chains

# %% [markdown]
# ### Get Option Expirations

# %%
path = '/v1/markets/options/expirations'

option_dates = pd.DataFrame()

for symbol in stock_table['symbol']:
    response = requests.get(f'{endpoint}{path}',
        params={'symbol': f'{symbol}', 
                'includeAllRoots': 'true'},
        headers={'Authorization': f'Bearer {token}', 
                 'Accept': 'application/json'}
    )
    
    these_dates = pd.DataFrame({'exp_dates': response.json()['expirations']['date'],
                                'symbol': symbol})
    option_dates = pd.concat([option_dates, these_dates], axis = 0, ignore_index = True)

# %%
option_dates
# Out:
#       exp_dates symbol
# 0    2022-12-16   CASH
# 1    2023-01-20   CASH
# 2    2023-03-17   CASH
# 3    2023-06-16   CASH
# 4    2022-12-16   QYLD
# ..          ...    ...
# 645  2023-01-20   RKLB
# 646  2023-04-21   RKLB
# 647  2023-07-21   RKLB
# 648  2024-01-19   RKLB
# 649  2025-01-17   RKLB
#
# [650 rows x 2 columns]

# %% [markdown]
# ### Get Put Chains

# %%
path = '/v1/markets/options/chains'

all_puts = pd.DataFrame()

for symbol in stock_table['symbol']:
    dates = option_dates.loc[option_dates['symbol'] == symbol]
    for date in dates['exp_dates']:
        response = requests.get(f'{endpoint}{path}',
            params={'symbol': f'{symbol}', 
                    'expiration': f'{date}', 
                    'greeks': 'true'},
            headers={'Authorization': f'Bearer {token}', 
                     'Accept': 'application/json'}
        )

        json_response = response.json()

        tmp = pd.json_normalize(json_response['options']['option'])
        tmp = tmp.loc[tmp['option_type'] == 'put']

        all_puts = pd.concat([all_puts, tmp], axis = 0, ignore_index = True)

# %%
all_puts
# Out:
#                     symbol                  description exch    type  last  \
# 0      CASH221216P00017500  CASH Dec 16 2022 $17.50 Put    Z  option   NaN
# 1      CASH221216P00020000  CASH Dec 16 2022 $20.00 Put    Z  option   NaN
# 2      CASH221216P00022500  CASH Dec 16 2022 $22.50 Put    Z  option   NaN
# 3      CASH221216P00025000  CASH Dec 16 2022 $25.00 Put    Z  option   0.7
# 4      CASH221216P00030000  CASH Dec 16 2022 $30.00 Put    Z  option  0.15
# ...                    ...                          ...  ...     ...   ...
# 24762  RKLB250117P00003000   RKLB Jan 17 2025 $3.00 Put    Z  option  1.05
# 24763  RKLB250117P00004000   RKLB Jan 17 2025 $4.00 Put    Z  option   1.6
# 24764  RKLB250117P00005000   RKLB Jan 17 2025 $5.00 Put    Z  option   2.3
# 24765  RKLB250117P00007000   RKLB Jan 17 2025 $7.00 Put    Z  option   3.1
# 24766  RKLB250117P00010000  RKLB Jan 17 2025 $10.00 Put    Z  option   6.2
#
#       change  volume  open  high   low close   bid   ask underlying  strike  \
# 0        NaN       0   NaN   NaN   NaN   NaN  0.00  0.80       CASH    17.5
# 1        NaN       0   NaN   NaN   NaN   NaN  0.00  0.05       CASH    20.0
# 2        NaN       0   NaN   NaN   NaN   NaN  0.00  0.80       CASH    22.5
# 3        0.0       0   NaN   NaN   NaN   NaN  0.00  0.15       CASH    25.0
# 4        0.0       0   NaN   NaN   NaN   NaN  0.00  0.80       CASH    30.0
# ...      ...     ...   ...   ...   ...   ...   ...   ...        ...     ...
# 24762   0.05       1  1.05  1.05  1.05  1.05  0.75  1.30       RKLB     3.0
# 24763    0.0       0   NaN   NaN   NaN   NaN  1.25  2.15       RKLB     4.0
# 24764    0.0       0   NaN   NaN   NaN   NaN  2.00  2.90       RKLB     5.0
# 24765    0.0       0   NaN   NaN   NaN   NaN  3.10  4.60       RKLB     7.0
# 24766   0.22       1   6.2   6.2   6.2   6.2  6.10  6.80       RKLB    10.0
#
#       change_percentage  average_volume  last_volume     trade_date prevclose  \
# 0                   NaN               0            0              0       NaN
# 1                   NaN               0            0              0       NaN
# 2                   NaN               0            0              0       NaN
# 3                   0.0               0            1  1659965460356       0.7
# 4                   0.0               0            5  1668532363544      0.15
# ...                 ...             ...          ...            ...       ...
# 24762               5.0               0            1  1669392486484       1.0
# 24763               0.0               0            4  1669225276647       1.6
# 24764               0.0               0            1  1669231198777       2.3
# 24765               0.0               0            3  1668609239331       3.1
# 24766              3.68               0            1  1669388648775      5.98
#
#        week_52_high  week_52_low  bidsize bidexch       bid_date  asksize  \
# 0               0.0          0.0        0       Q  1669387040000       82
# 1               0.0          0.0        0       A  1669386617000        2
# 2               0.0          0.0        0       Q  1669387040000       81
# 3               0.0          0.0        0       W  1669396688000       37
# 4               0.0          0.0        0       Q  1669387040000       83
# ...             ...          ...      ...     ...            ...      ...
# 24762           0.0          0.0      212       B  1669399080000        2
# 24763           0.0          0.0      147       B  1669399169000      217
# 24764           0.0          0.0        1       N  1669399185000       56
# 24765           0.0          0.0      135       B  1669399169000      120
# 24766           0.0          0.0        1       P  1669399173000        1
#
#       askexch       ask_date  open_interest  contract_size expiration_date  \
# 0           C  1669399080000              0            100      2022-12-16
# 1           D  1669386616000              0            100      2022-12-16
# 2           A  1669399081000              0            100      2022-12-16
# 3           B  1669396690000             30            100      2022-12-16
# 4           C  1669399081000             84            100      2022-12-16
# ...       ...            ...            ...            ...             ...
# 24762       A  1669392486000             15            100      2025-01-17
# 24763       E  1669399142000           1042            100      2025-01-17
# 24764       B  1669399185000             43            100      2025-01-17
# 24765       B  1669399169000              4            100      2025-01-17
# 24766       P  1669399173000             34            100      2025-01-17
#
#       expiration_type option_type root_symbol  greeks.delta  greeks.gamma  \
# 0            standard         put        CASH      0.000000  1.770891e-15
# 1            standard         put        CASH      0.000000  1.770891e-15
# 2            standard         put        CASH      0.000000  1.770891e-15
# 3            standard         put        CASH      0.000000  1.770891e-15
# 4            standard         put        CASH      0.000000  1.770891e-15
# ...               ...         ...         ...           ...           ...
# 24762        standard         put        RKLB     -0.158352  4.157843e-02
# 24763        standard         put        RKLB     -0.213089  5.028727e-02
# 24764        standard         put        RKLB     -0.262191  5.648857e-02
# 24765        standard         put        RKLB     -0.350790  6.481446e-02
# 24766        standard         put        RKLB     -0.452505  6.979525e-02
#
#        greeks.theta  greeks.vega  greeks.rho  greeks.phi  greeks.bid_iv  \
# 0     -1.690108e-14     0.000020    0.000000    0.000000       0.000000
# 1     -1.690108e-14     0.000020    0.000000    0.000000       0.000000
# 2     -1.690108e-14     0.000020    0.000000    0.000000       0.000000
# 3     -1.690108e-14     0.000020    0.000000    0.000000       0.000000
# 4     -1.690108e-14     0.000020    0.000000    0.000000       0.000000
# ...             ...          ...         ...         ...            ...
# 24762 -1.010638e-03     0.014861    0.020589   -0.075676       0.695346
# 24763 -1.204106e-03     0.017905    0.021771   -0.070742       0.663473
# 24764 -1.342242e-03     0.020007    0.022214   -0.066311       0.708433
# 24765 -1.495735e-03     0.023045    0.022092   -0.058321       0.536960
# 24766 -1.581596e-03     0.024310    0.020761   -0.049156       0.710941
#
#        greeks.mid_iv  greeks.ask_iv  greeks.smv_vol    greeks.updated_at  \
# 0           2.889865       2.889865           0.309  2022-11-25 17:58:39
# 1           1.485829       1.485829           0.309  2022-11-25 17:58:39
# 2           2.202682       2.202682           0.309  2022-11-25 17:58:39
# 3           1.307778       1.307778           0.309  2022-11-25 17:58:39
# 4           1.409931       1.409931           0.309  2022-11-25 17:58:39
# ...              ...            ...             ...                  ...
# 24762       0.871985       1.048624           0.909  2022-11-25 17:58:59
# 24763       0.911214       1.158955           0.915  2022-11-25 17:58:59
# 24764       0.935276       1.162119           0.924  2022-11-25 17:58:59
# 24765       0.873376       1.209792           0.913  2022-11-25 17:58:59
# 24766       0.891365       1.071789           0.907  2022-11-25 17:58:59
#
#        greeks
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 24762     NaN
# 24763     NaN
# 24764     NaN
# 24765     NaN
# 24766     NaN
#
# [24767 rows x 46 columns]

# %% [markdown]
# ### Simulate Stock Prices

# %%
num_samples = 10000
sample_size = 20000 
upper_scale = 0.60 
upper_shape = -0.09 
lower_scale = 0.65 
lower_shape = -0.1
today = datetime.utcnow().date()

final_options = pd.DataFrame()

for symbol in all_puts['underlying']:
    opt_chain = all_puts.loc[all_puts['underlying'] == symbol]
    opt_chain['strike_minus_last'] = opt_chain['strike'] - opt_chain['ask']
    hist_price = all_stock_history.loc[all_stock_history['symbol'] == symbol]
    hist_price['perc_change'] = ((hist_price['close'] - hist_price['open']) / hist_price['open'])
    
    for option_date in opt_chain['expiration_date']:
        this_opt_chain = opt_chain.loc[opt_chain['expiration_date'] == option_date]
        
        date = {"Date": pd.date_range(today, option_date)}

        dates = pd.DataFrame(data = date)
        dates['wday'] = dates['Date'].dt.dayofweek
        dates = dates.loc[dates['wday'] != 5]
        dates = dates.loc[dates['wday'] != 6]

        num_trading_days = dates.shape[0]

        start = today - timedelta(days = num_trading_days)
        start = start.isoformat()

        perc_pos = (
            sum(hist_price.loc[hist_price['date'] > start, 'perc_change'] > 0) / 
            len(hist_price.loc[hist_price['date'] > start, 'perc_change'])
        )

        perc_neg = 1 - perc_pos

        avg = np.mean(hist_price['perc_change'])
        std = np.std(hist_price['perc_change'])

        samp_upper = genextreme.rvs(upper_shape, 
                                    loc = avg, 
                                    scale = upper_scale * std,
                                    size = round(sample_size * perc_pos))

        samp_lower = -1 * genextreme.rvs(lower_shape, 
                                         loc = avg, 
                                         scale = lower_scale * std,
                                         size = round(sample_size * perc_neg))

        samp = np.append(samp_upper, samp_lower)
        
        del samp_upper
        del samp_lower

        sample_col = pd.Series(range(1, num_trading_days + 1)).repeat(num_samples)
        dates_col = dates['Date'].repeat(num_samples)
        sample_values = np.array(choices(samp + 1, 
                                         k = num_samples * num_trading_days
                                         )).reshape(num_trading_days, 
                                                    num_samples)

        start_price = all_stock_history['close'].iloc[-1]

        sample_values[0] = start_price

        price_paths = sample_values.cumprod(axis = 0)

        final_prices = price_paths[num_trading_days - 1]

        del price_paths

        for strp in this_opt_chain.strike:
            this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
                sum(final_prices < this_opt_chain['strike_minus_last'].loc[this_opt_chain['strike'] == strp].item()) / num_samples)

            this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)

        this_opt_chain = this_opt_chain.rename(({'strike_minus_last': 'Effective Price',
                                                 'last': 'Last Price',
                                                 'expiration_date': 'Expiration Date',
                                                 'likelihood_below': 'Llhd Blw EP',
                                                 'likelihood_strike': 'Llhd Blw Stk'}),
                                                axis = 'columns')
        
        final_options = pd.concat([final_options, opt_chain], axis = 0, ignore_index = True)
# Out:
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   opt_chain['strike_minus_last'] = opt_chain['strike'] - opt_chain['ask']
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hist_price['perc_change'] = ((hist_price['close'] - hist_price['open']) / hist_price['open'])
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   opt_chain['strike_minus_last'] = opt_chain['strike'] - opt_chain['ask']
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hist_price['perc_change'] = ((hist_price['close'] - hist_price['open']) / hist_price['open'])
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# ...
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_below'] = (
# /var/folders/vf/7cq04w71629bcwjv6x0n0nm80000gn/T/ipykernel_84911/3477351884.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_opt_chain.loc[this_opt_chain['strike'] == strp, 'likelihood_strike'] = (sum(final_prices < strp) / num_samples)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [43], line 59
#      57 sample_col = pd.Series(range(1, num_trading_days + 1)).repeat(num_samples)
#      58 dates_col = dates['Date'].repeat(num_samples)
# ---> 59 sample_values = np.array(choices(samp + 1,
#      60                                  k = num_samples * num_trading_days
#      61                                  )).reshape(num_trading_days,
#      62                                             num_samples)
#      64 start_price = all_stock_history['close'].iloc[-1]
#      66 sample_values[0] = start_price
#
# File ~/opt/anaconda3/envs/rle_finance/lib/python3.10/random.py:519, in Random.choices(self, population, weights, cum_weights, k)
#     517     floor = _floor
#     518     n += 0.0    # convert to float for a small speed improvement
# --> 519     return [population[floor(random() * n)] for i in _repeat(None, k)]
#     520 try:
#     521     cum_weights = list(_accumulate(weights))
#
# File ~/opt/anaconda3/envs/rle_finance/lib/python3.10/random.py:519, in <listcomp>(.0)
#     517     floor = _floor
#     518     n += 0.0    # convert to float for a small speed improvement
# --> 519     return [population[floor(random() * n)] for i in _repeat(None, k)]
#     520 try:
#     521     cum_weights = list(_accumulate(weights))
#
# KeyboardInterrupt:

# %%
final_options
# Out:
#                     symbol                  description exch    type  last  \
# 0      CASH221216P00017500  CASH Dec 16 2022 $17.50 Put    Z  option   NaN
# 1      CASH221216P00020000  CASH Dec 16 2022 $20.00 Put    Z  option   NaN
# 2      CASH221216P00022500  CASH Dec 16 2022 $22.50 Put    Z  option   NaN
# 3      CASH221216P00025000  CASH Dec 16 2022 $25.00 Put    Z  option   0.7
# 4      CASH221216P00030000  CASH Dec 16 2022 $30.00 Put    Z  option  0.15
# ...                    ...                          ...  ...     ...   ...
# 45985  CASH230616P00045000  CASH Jun 16 2023 $45.00 Put    Z  option   NaN
# 45986  CASH230616P00050000  CASH Jun 16 2023 $50.00 Put    Z  option   NaN
# 45987  CASH230616P00055000  CASH Jun 16 2023 $55.00 Put    Z  option   NaN
# 45988  CASH230616P00060000  CASH Jun 16 2023 $60.00 Put    Z  option   NaN
# 45989  CASH230616P00065000  CASH Jun 16 2023 $65.00 Put    Z  option   NaN
#
#       change  volume open high  low close   bid    ask underlying  strike  \
# 0        NaN       0  NaN  NaN  NaN   NaN   0.0   0.80       CASH    17.5
# 1        NaN       0  NaN  NaN  NaN   NaN   0.0   0.05       CASH    20.0
# 2        NaN       0  NaN  NaN  NaN   NaN   0.0   0.80       CASH    22.5
# 3        0.0       0  NaN  NaN  NaN   NaN   0.0   0.15       CASH    25.0
# 4        0.0       0  NaN  NaN  NaN   NaN   0.0   0.80       CASH    30.0
# ...      ...     ...  ...  ...  ...   ...   ...    ...        ...     ...
# 45985    NaN       0  NaN  NaN  NaN   NaN   3.2   5.60       CASH    45.0
# 45986    NaN       0  NaN  NaN  NaN   NaN   6.8   8.50       CASH    50.0
# 45987    NaN       0  NaN  NaN  NaN   NaN  10.4  12.20       CASH    55.0
# 45988    NaN       0  NaN  NaN  NaN   NaN  14.1  16.80       CASH    60.0
# 45989    NaN       0  NaN  NaN  NaN   NaN  19.7  21.40       CASH    65.0
#
#       change_percentage  average_volume  last_volume     trade_date prevclose  \
# 0                   NaN               0            0              0       NaN
# 1                   NaN               0            0              0       NaN
# 2                   NaN               0            0              0       NaN
# 3                   0.0               0            1  1659965460356       0.7
# 4                   0.0               0            5  1668532363544      0.15
# ...                 ...             ...          ...            ...       ...
# 45985               NaN               0            0              0       NaN
# 45986               NaN               0            0              0       NaN
# 45987               NaN               0            0              0       NaN
# 45988               NaN               0            0              0       NaN
# 45989               NaN               0            0              0       NaN
#
#        week_52_high  week_52_low  bidsize bidexch       bid_date  asksize  \
# 0               0.0          0.0        0       Q  1669387040000       82
# 1               0.0          0.0        0       A  1669386617000        2
# 2               0.0          0.0        0       Q  1669387040000       81
# 3               0.0          0.0        0       W  1669396688000       37
# 4               0.0          0.0        0       Q  1669387040000       83
# ...             ...          ...      ...     ...            ...      ...
# 45985           0.0          0.0       75       E  1669399080000       46
# 45986           0.0          0.0       31       A  1669399183000       40
# 45987           0.0          0.0       43       B  1669399082000       40
# 45988           0.0          0.0      119       E  1669399141000       41
# 45989           0.0          0.0       32       B  1669399177000       40
#
#       askexch       ask_date  open_interest  contract_size expiration_date  \
# 0           C  1669399080000              0            100      2022-12-16
# 1           D  1669386616000              0            100      2022-12-16
# 2           A  1669399081000              0            100      2022-12-16
# 3           B  1669396690000             30            100      2022-12-16
# 4           C  1669399081000             84            100      2022-12-16
# ...       ...            ...            ...            ...             ...
# 45985       B  1669399123000              0            100      2023-06-16
# 45986       B  1669399187000              0            100      2023-06-16
# 45987       B  1669399082000              0            100      2023-06-16
# 45988       B  1669399088000              0            100      2023-06-16
# 45989       B  1669399177000              0            100      2023-06-16
#
#       expiration_type option_type root_symbol  greeks.delta  greeks.gamma  \
# 0            standard         put        CASH      0.000000  1.770891e-15
# 1            standard         put        CASH      0.000000  1.770891e-15
# 2            standard         put        CASH      0.000000  1.770891e-15
# 3            standard         put        CASH      0.000000  1.770891e-15
# 4            standard         put        CASH      0.000000  1.770891e-15
# ...               ...         ...         ...           ...           ...
# 45985        standard         put        CASH     -0.400176  2.938224e-02
# 45986        standard         put        CASH     -0.554103  3.124103e-02
# 45987        standard         put        CASH     -0.692610  2.838089e-02
# 45988        standard         put        CASH     -0.797121  2.293053e-02
# 45989        standard         put        CASH     -0.871241  1.702591e-02
#
#        greeks.theta  greeks.vega  greeks.rho  greeks.phi  greeks.bid_iv  \
# 0     -1.690108e-14     0.000020    0.000000    0.000000       0.000000
# 1     -1.690108e-14     0.000020    0.000000    0.000000       0.000000
# 2     -1.690108e-14     0.000020    0.000000    0.000000       0.000000
# 3     -1.690108e-14     0.000020    0.000000    0.000000       0.000000
# 4     -1.690108e-14     0.000020    0.000000    0.000000       0.000000
# ...             ...          ...         ...         ...            ...
# 45985 -1.616236e-02     0.128676    0.116951   -0.149677       0.283715
# 45986 -1.484711e-02     0.133824    0.091090   -0.111267       0.323158
# 45987 -1.230585e-02     0.116767    0.064839   -0.076705       0.281838
# 45988 -9.569565e-03     0.095837    0.043708   -0.050625       0.000000
# 45989 -6.951447e-03     0.070639    0.028163   -0.032130       0.000000
#
#        greeks.mid_iv  greeks.ask_iv  greeks.smv_vol    greeks.updated_at  \
# 0           2.889865       2.889865           0.309  2022-11-25 17:58:39
# 1           1.485829       1.485829           0.309  2022-11-25 17:58:39
# 2           2.202682       2.202682           0.309  2022-11-25 17:58:39
# 3           1.307778       1.307778           0.309  2022-11-25 17:58:39
# 4           1.409931       1.409931           0.309  2022-11-25 17:58:39
# ...              ...            ...             ...                  ...
# 45985       0.376994       0.470273           0.393  2022-11-25 17:58:39
# 45986       0.389887       0.456615           0.380  2022-11-25 17:58:39
# 45987       0.370969       0.460101           0.374  2022-11-25 17:58:39
# 45988       0.510875       0.510875           0.361  2022-11-25 17:58:39
# 45989       0.550019       0.550019           0.356  2022-11-25 17:58:39
#
#        greeks  strike_minus_last
# 0         NaN              16.70
# 1         NaN              19.95
# 2         NaN              21.70
# 3         NaN              24.85
# 4         NaN              29.20
# ...       ...                ...
# 45985     NaN              39.40
# 45986     NaN              41.50
# 45987     NaN              42.80
# 45988     NaN              43.20
# 45989     NaN              43.60
#
# [45990 rows x 47 columns]

# %%
start_price = this_stock_history['close'].iloc[-1]

# %%
start_price
# Out:
# 65.5617
